# %% [markdown]
# # Exercise 4: Sales List Analysis
#
# ### Given:
#
# monthly_sales = [85000, 120000, 95000, 140000, 75000, 160000]
#
# ### Create:
#
# A sorted list from highest to lowest.
#
# A list containing only values above 100000.
#
# A list where each amount has 13% tax added.
#
# The total sales amount.
#
# The average sales amount.
#
# ### Use comprehensions where appropriate.

# %%
monthly_sales = [85000, 120000, 95000, 140000, 75000, 160000]

# %%
# A sorted list from highest to lowest.
monthly_sales.sort(reverse=True)
print(monthly_sales)
# Out:
# [160000, 140000, 120000, 95000, 85000, 75000]

# %%
# A list containing only values above 100000.
list_above_100000 = [value for value in monthly_sales if value > 100000]
print(list_above_100000)
# Out:
# [160000, 140000, 120000]

# %%
# A list where each amount has 13% tax added.
tax_percentage = 13
list_with_vat = [value+(value*tax_percentage /100) for value in monthly_sales]
print(list_with_vat)
# Out:
# [180800.0, 158200.0, 135600.0, 107350.0, 96050.0, 84750.0]

# %%
# The total sales amount.
total_sale = 0
for value in monthly_sales:
    total_sale += value

print(total_sale)
# Out:
# 675000

# %%
# The average sales amount.
number_of_element = len(monthly_sales)
average_sale = total_sale/number_of_element
print(average_sale)
# Out:
# 112500.0
